# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\Dell\\Documents\\csv.csv') # save the CSV in local folder first and then reading from there

# %%
df =pd.DataFrame(data)

# %%
df.count
# Out:
# <bound method DataFrame.count of          Unnamed: 0       Id       Name  Year Gender State  Count
# 0             11349    11350       Emma  2004      F    AK     62
# 1             11350    11351    Madison  2004      F    AK     48
# 2             11351    11352     Hannah  2004      F    AK     46
# 3             11352    11353      Grace  2004      F    AK     44
# 4             11353    11354      Emily  2004      F    AK     41
# 5             11354    11355    Abigail  2004      F    AK     37
# 6             11355    11356     Olivia  2004      F    AK     33
# 7             11356    11357   Isabella  2004      F    AK     30
# 8             11357    11358     Alyssa  2004      F    AK     29
# 9             11358    11359     Sophia  2004      F    AK     28
# 10            11359    11360     Alexis  2004      F    AK     27
# 11            11360    11361  Elizabeth  2004      F    AK     27
# 12            11361    11362     Hailey  2004      F    AK     27
# ...

# %%
#Delete unnamed columns 
df.drop('Unnamed: 0', axis=1)
# Out:
#               Id       Name  Year Gender State  Count
# 0          11350       Emma  2004      F    AK     62
# 1          11351    Madison  2004      F    AK     48
# 2          11352     Hannah  2004      F    AK     46
# 3          11353      Grace  2004      F    AK     44
# 4          11354      Emily  2004      F    AK     41
# 5          11355    Abigail  2004      F    AK     37
# 6          11356     Olivia  2004      F    AK     33
# 7          11357   Isabella  2004      F    AK     30
# 8          11358     Alyssa  2004      F    AK     29
# 9          11359     Sophia  2004      F    AK     28
# 10         11360     Alexis  2004      F    AK     27
# 11         11361  Elizabeth  2004      F    AK     27
# 12         11362     Hailey  2004      F    AK     27
# 13         11363       Anna  2004      F    AK     26
# 14         11364    Natalie  2004      F    AK     25
# 15         11365      Sarah  2004      F    AK     25
# ...

# %%
# show the distribution of male and female
group_by = df.groupby('Gender')
group_by.describe()
# Out:
#            Count                                                       \
#            count       mean         std  min  25%   50%   75%     max
# Gender
# F       558846.0  29.310925   75.962992  5.0  6.0  10.0  23.0  3634.0
# M       457549.0  41.615650  118.074308  5.0  7.0  12.0  29.0  4167.0
#
#               Id                 ...    Unnamed: 0                 Year  \
#            count          mean   ...           75%        max     count
# Gender                           ...
# F       558846.0  2.793178e+06   ...    4333050.75  5634123.0  558846.0
# M       457549.0  2.877176e+06   ...    4241791.00  5647425.0  457549.0
#
#
#                mean       std     min     25%     50%     75%     max
# Gender
# F       2009.026258  3.137428  2004.0  2006.0  2009.0  2012.0  2014.0
# M       2009.086085  3.139039  2004.0  2006.0  2009.0  2012.0  2014.0
#
# [2 rows x 32 columns]

# %%
# show the preferred names 
df1 = df.head(5).groupby('Name')

# %%
df1.head(5)
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
#median data 
df.median()
# Out:
# Unnamed: 0    2811920.0
# Id            2811921.0
# Year             2009.0
# Count              11.0
# dtype: float64

# %%
# group by States and Gender
Df2= df.groupby(['State','Gender']).count()

# %%
Df2.loc[: , "Count"]
# Out:
# State  Gender
# AK     F          2404
#        M          2587
# AL     F          9878
#        M          8419
# AR     F          7171
#        M          6475
# AZ     F         14518
#        M         10820
# CA     F         45144
#        M         31637
# CO     F         11424
#        M          9183
# CT     F          6575
#        M          5733
# DC     F          3053
#        M          3000
# DE     F          2549
#        M          2440
# FL     F         25781
#        M         20070
# GA     F         19385
#        M         15454
# HI     F          3255
#        M          3546
# IA     F          7131
#        M          6307
# ID     F          4918
#        M          4833
# IL     F         21268
#        M         16828
#                  ...
# OK     F          9519
#        M          8138
# OR     F          8604
#        M          7333
# PA     F         17480
#        M         14171
# RI     F          2558
#        M          2468
# ...
